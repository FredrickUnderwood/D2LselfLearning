# %%
import matplotlib.pyplot as plt
from PIL import Image

# %%
img = Image.open('1001320321_0.jpg')
print('image_id:1001320321.jpg, predictions:0.990 	0.071 	-0.119 	-0.021 	0.002, predict_label:0 CBB , actual_label:0 CBB')
plt.imshow(img)
# Out:
# image_id:1001320321.jpg, predictions:0.990 	0.071 	-0.119 	-0.021 	0.002, predict_label:0 CBB , actual_label:0 CBB

# %%
img = Image.open('1000723321_1.jpg')
print('image_id:1000723321.jpg, predictions:-0.047 	0.997 	-0.046 	-0.010 	-0.043, predict_label:1 CBSD , actual_label:1 CBSD')
plt.imshow(img)
# Out:
# image_id:1000723321.jpg, predictions:-0.047 	0.997 	-0.046 	-0.010 	-0.043, predict_label:1 CBSD , actual_label:1 CBSD

# %%
img = Image.open('1003218714_2.jpg')
print('image_id:1003218714.jpg, predictions:-0.076 	-0.024 	0.978 	0.192 	-0.005, predict_label:2 CGM , actual_label:2 CGM')
plt.imshow(img)
# Out:
# image_id:1003218714.jpg, predictions:-0.076 	-0.024 	0.978 	0.192 	-0.005, predict_label:2 CGM , actual_label:2 CGM

# %%
img = Image.open('1000201771_3.jpg')
print('image_id:1000201771.jpg, predictions:-0.020 	-0.021 	-0.013 	0.999 	-0.003, predict_label:3 CMD , actual_label:3 CMD')
plt.imshow(img)
# Out:
# image_id:1000201771.jpg, predictions:-0.020 	-0.021 	-0.013 	0.999 	-0.003, predict_label:3 CMD , actual_label:3 CMD

# %%
img = Image.open('1003442061_4.jpg')
print('image_id:1003442061.jpg, predictions:-0.035 	-0.005 	0.003 	-0.017 	0.999, predict_label:4 Healthy , actual_label:4 Healthy')
plt.imshow(img)
# Out:
# image_id:1003442061.jpg, predictions:-0.035 	-0.005 	0.003 	-0.017 	0.999, predict_label:4 Healthy , actual_label:4 Healthy
